# %%
import pandas as pd

# %%
xls = pd.ExcelFile('OfferTag_1120.xlsx')
offer_label_table = xls.parse('OFFER ID')
offer_label_table.head()
# Out:
#         OFFER OFFER_ID                                                 網址  \
# 0        夜間換匯  OFF0001  https://www.esunbank.com.tw/event/b2b/night_on...
# 1   臺幣活存轉外幣定存  OFF0002          https://www.esunbank.com.tw/event/b2c/eb/
# 2    外幣理財首選網銀  OFF0003      https://www.esunbank.com.tw/event/b2c/eb/pib/
# 3  擁有外幣帳戶三大理由  OFF0004      https://www.esunbank.com.tw/event/b2c/eb/acc/
# 4        連假攻略  OFF0005  https://www.esunbank.com.tw/event/forex/market...
#
#   LABEL_1 LABEL_2 LABEL_3 LABEL_4 LABEL_5 LABEL_6 LABEL_7   ...    LABEL_9  \
# 0      外幣    網路換匯    網路交易      匯率      優惠    網路銀行    行動銀行   ...        NaN
# 1     低起存     短存期     高利率    網銀限定      外幣     NaN     NaN   ...        NaN
# 2      外幣    外幣投資    網路交易      存錢      儲蓄     NaN     NaN   ...        NaN
# 3      外幣    外幣帳戶    網路銀行      優惠      匯差     雙幣卡    海外刷卡   ...         便利
# 4    旅遊攻略      出國      外幣    國外旅遊      優惠      匯率    機場接送   ...       行動銀行
#
# ...

# %%
offer_label_tag = []
offer_label_tag.append(list(offer_label_table)[3:])
offer_label_tag
# Out:
# [[u'LABEL_1',
#   u'LABEL_2',
#   u'LABEL_3',
#   u'LABEL_4',
#   u'LABEL_5',
#   u'LABEL_6',
#   u'LABEL_7',
#   u'LABEL_8',
#   u'LABEL_9',
#   u'LABEL_10',
#   u'LABEL_11',
#   u'LABEL_12',
#   u'LABEL_13',
#   u'LABEL_14',
#   u'LABEL_15',
#   u'LABEL_16',
#   u'LABEL_17',
#   u'LABEL_18']]

# %%
offer_label_table['offer_label_list'] = ""
offer_list_Json = []
for i in range(offer_label_table.shape[0]):
    temp_list = []
    temp_detail = {}
    temp_detail['offer_id'] = str(offer_table.loc[i,:]['OFFER_ID'])
    
    for column in offer_tag:
        temp_list.append(offer_table.loc[i,:][column])
    offer_table.loc[i,:]['offer_list'] = temp_list
    temp_detail['offer_list'] = temp_list
    offer_Json.append(temp_detail)
